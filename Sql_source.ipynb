# %%
import pandas as pd 
import numpy as np 
import os

# %%
os.getcwd()
# Out:
# '/Users/anshushrestha/Desktop/Codebase/Code/Sql_code'

# %%
import sqlite3

# %%
#!pip install ipython-sql

# %%
df = pd.read_csv('/Users/anshushrestha/Desktop/Codebase/Data/house_price.csv')

# %%
df_test = df.head(20)

# %%
'''
Download data 
Create connection 
Push data into connection 
Connect to SQL
Query SQL 
'''

# %%
cnn = sqlite3.connect('jupyter_sql_tutorial.db')

# %%
df_test.to_sql('house_data', cnn)
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df_test.to_sql('house_data', cnn)
#       2 get_ipython().run_line_magic('load_ext', 'sql')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
# ...

# %%
# %sql sqlite:///jupyter_sql_tutorial.db

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# select * from house_data
# limit 10
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [(0, 1461, 20, 'RH', 80.0, 11622, 'Pave', None, 'Reg', 'Lvl', 'AllPub', 'Inside', 'Gtl', 'NAmes', 'Feedr', 'Norm', '1Fam', '1Story', 5, 6, 1961, 1961, 'Gable', 'CompShg', 'VinylSd', 'VinylSd', None, 0.0, 'TA', 'TA', 'CBlock', 'TA', 'TA', 'No', 'Rec', 468.0, 'LwQ', 144.0, 270.0, 882.0, 'GasA', 'TA', 'Y', 'SBrkr', 896, 0, 0, 896, 0.0, 0.0, 1, 0, 2, 1, 'TA', 5, 'Typ', 0, None, 'Attchd', 1961.0, 'Unf', 1.0, 730.0, 'TA', 'TA', 'Y', 140, 0, 0, 0, 120, 0, None, 'MnPrv', None, 0, 6, 2010, 'WD', 'Normal'),
# ...
